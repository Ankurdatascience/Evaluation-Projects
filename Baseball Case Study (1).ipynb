# %% [markdown]
# # Baseball Case Study

# %% [markdown]
# # Problem Statement

# %% [markdown]
# This dataset utilizes data from 2014 Major League Baseball seasons in order to develop an algorithm that predicts the number of wins for a given team in the 2015 season based on several different indicators of success. There are 16 different features that will be used as the inputs to the machine learning and the output will be a value that represents the number of wins.
#
# Input features: Runs, At Bats, Hits, Doubles, Triples, Homeruns, Walks, Strikeouts, Stolen Bases, Runs Allowed, Earned Runs, Earned Run Average (ERA), Shutouts, Saves, and Errors
#
# Output: Number of predicted wins (W)

# %% [markdown]
# # Attribute Information

# %% [markdown]
# W - WIN (Target Variable)
#
# R - Runs
#
# AB - At Bats
#
# H - Hits
#
# 2B - Doubles
#
# 3B - Triples
#
# HR - Homeruns
#
# BB - Walks
#
# SO - Strikeouts
#
# SB - Stolen Bases
#
# RA - Runs Allowed
#
# ER - Earned Runs
#
# ERA - Earned Run Average
#
# SHO - Shutouts
#
# SV - Saves
#
# E - Errors

# %% [markdown]
# # Importing Requried Library

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %%
# Loading the Dataset
df=pd.read_csv('baseball.csv')
df.head()
# Out:
#     W    R    AB     H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  CG  SHO  \
# 0  95  724  5575  1497  300  42  139  383   973  104  641  601  3.73   2    8
# 1  83  696  5467  1349  277  44  156  439  1264   70  700  653  4.07   2   12
# 2  81  669  5439  1395  303  29  141  533  1157   86  640  584  3.67  11   10
# 3  76  622  5533  1381  260  27  136  404  1231   68  701  643  3.98   7    9
# 4  74  689  5605  1515  289  49  151  455  1259   83  803  746  4.64   7   12
#
#    SV    E
# 0  56   88
# 1  45   86
# 2  38   79
# 3  37  101
# 4  35   86

# %%
df.shape
# Out:
# (30, 17)

# %% [markdown]
# This dataset have 30 rows and 17 columns
#
# As our target is in numerical/integer format we can say that this is a regression problem Statement

# %%
df.dtypes
# Out:
# W        int64
# R        int64
# AB       int64
# H        int64
# 2B       int64
# 3B       int64
# HR       int64
# BB       int64
# SO       int64
# SB       int64
# RA       int64
# ER       int64
# ERA    float64
# CG       int64
# SHO      int64
# SV       int64
# E        int64
# dtype: object

# %% [markdown]
# In this dataset all atributes are 'Int64' except ERA which is "float64"

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 17 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   W       30 non-null     int64
#  1   R       30 non-null     int64
#  2   AB      30 non-null     int64
#  3   H       30 non-null     int64
#  4   2B      30 non-null     int64
#  5   3B      30 non-null     int64
#  6   HR      30 non-null     int64
#  7   BB      30 non-null     int64
#  8   SO      30 non-null     int64
#  9   SB      30 non-null     int64
#  10  RA      30 non-null     int64
#  11  ER      30 non-null     int64
#  12  ERA     30 non-null     float64
#  13  CG      30 non-null     int64
#  14  SHO     30 non-null     int64
#  15  SV      30 non-null     int64
#  16  E       30 non-null     int64
# dtypes: float64(1), int64(16)
# memory usage: 4.1 KB

# %% [markdown]
# From this observation we can say that all features have similar number of rows means no null values present.

# %% [markdown]
# # Checcking Null values

# %%
df.isnull().sum()
# Out:
# W      0
# R      0
# AB     0
# H      0
# 2B     0
# 3B     0
# HR     0
# BB     0
# SO     0
# SB     0
# RA     0
# ER     0
# ERA    0
# CG     0
# SHO    0
# SV     0
# E      0
# dtype: int64

# %% [markdown]
# No Null value is present. Let's see it by heatmap as well.

# %%
plt.figure(figsize=(15,6))
plt.title('NUll Values Heatmap',fontsize=18)
sns.heatmap(df.isnull())
# Out:
# <AxesSubplot:title={'center':'NUll Values Heatmap'}>

# %% [markdown]
# There is no null value in our dataset

# %%
df.describe()
# Out:
#                 W           R           AB            H          2B  \
# count   30.000000   30.000000    30.000000    30.000000   30.000000
# mean    80.966667  688.233333  5516.266667  1403.533333  274.733333
# std     10.453455   58.761754    70.467372    57.140923   18.095405
# min     63.000000  573.000000  5385.000000  1324.000000  236.000000
# 25%     74.000000  651.250000  5464.000000  1363.000000  262.250000
# 50%     81.000000  689.000000  5510.000000  1382.500000  275.500000
# 75%     87.750000  718.250000  5570.000000  1451.500000  288.750000
# max    100.000000  891.000000  5649.000000  1515.000000  308.000000
#
#               3B          HR          BB          SO          SB          RA  \
# count  30.000000   30.000000   30.000000    30.00000   30.000000   30.000000
# mean   31.300000  163.633333  469.100000  1248.20000   83.500000  688.233333
# std    10.452355   31.823309   57.053725   103.75947   22.815225   72.108005
# min    13.000000  100.000000  375.000000   973.00000   44.000000  525.000000
# 25%    23.000000  140.250000  428.250000  1157.50000   69.000000  636.250000
# 50%    31.000000  158.500000  473.000000  1261.50000   83.500000  695.500000
# 75%    39.000000  177.000000  501.250000  1311.50000   96.500000  732.500000
# max    49.000000  232.000000  570.000000  1518.00000  134.000000  844.000000
#
#                ER        ERA         CG        SHO         SV           E
# count   30.000000  30.000000  30.000000  30.000000  30.000000   30.000000
# mean   635.833333   3.956333   3.466667  11.300000  43.066667   94.333333
# std     70.140786   0.454089   2.763473   4.120177   7.869335   13.958889
# min    478.000000   2.940000   0.000000   4.000000  28.000000   75.000000
# 25%    587.250000   3.682500   1.000000   9.000000  37.250000   86.000000
# 50%    644.500000   4.025000   3.000000  12.000000  42.000000   91.000000
# 75%    679.250000   4.220000   5.750000  13.000000  46.750000   96.750000
# max    799.000000   5.040000  11.000000  21.000000  62.000000  126.000000

# %% [markdown]
# The above table clearly shows that for most of attributes  Mean and Median is approximately same
#
# In some attributes such as 'H','HR', Mean value is greater than Median value which means data is right skewed in Nature.
#
# Possiblity of outliers are very less in our dataset.

# %% [markdown]
# # Correlation Matrix

# %%
plt.figure(figsize=(15,6))
plt.title('Correlation Heat Map',fontsize=18)
sns.heatmap(df.corr(),annot=True,cmap='BuPu')
# Out:
# <AxesSubplot:title={'center':'Correlation Heat Map'}>

# %% [markdown]
# ER and ERA are highly correlated with each other. Ther are almost similar as they are showing 99% correlation on Correlation Plot.

# %%
df.corr()['W'].sort_values(ascending=False).drop(['W']).plot.bar(figsize=(15,8),grid=True,title='Correlation with Target',fontsize=15)
# Out:
# <AxesSubplot:title={'center':'Correlation with Target'}>

# %% [markdown]
# SV (Saves),BB (Walks),SHO (Shutouts) these are important features which are positivly correlated to our Target Attribute Wins.
#
# ERA(Earned Run Average),RA(Runs Allowed),ER these are the features which are highly negatively correlated to our target attribute.
#
# Feature like H(Hits),AB(at bats) has correlation value near to zero which means almost no significance for target attribute prediction.

# %% [markdown]
# # Data Visualization

# %%
plt.figure(figsize=(10,5))
sns.set_style('darkgrid')
plt.title('Saves Vs Number of Wins  ',fontsize=12)
sns.scatterplot(df['SV'],df['W'],data=df)
plt.show()

# %% [markdown]
# This scatter plot shows as Number of saves increase the Game winning Chances(numbers) also increases.

# %% [markdown]
# Here we get moderate linear relation

# %%
plt.figure(figsize=(10,5))
sns.set_style('darkgrid')
plt.title('Walks Vs Number of Wins  ',fontsize=12)
sns.scatterplot(df['BB'],df['W'],data=df,y_jitter=True)
plt.show()

# %% [markdown]
#  We can clearly see that as number of walks increases the Number of winnings also get increases.
#
#  In few points we can see higher winning number despite lower walks. we may consider that as absurdity in data and later we will correct it.

# %%
plt.figure(figsize=(10,5))
sns.set_style('darkgrid')
plt.title('Shutouts Vs Number of Wins  ',fontsize=12)
sns.scatterplot(df['SHO'],df['W'],data=df,y_jitter=True)
# Out:
# <AxesSubplot:title={'center':'Shutouts Vs Number of Wins  '}, xlabel='SHO', ylabel='W'>

# %% [markdown]
# Here we get a mix trend of our data points. In some points where shutouts are same are getting different winnings numbers.

# %%
plt.figure(figsize=(10,5))
sns.set_style('darkgrid')
plt.title('Earned Runs Vs Number of Wins  ',fontsize=12)
sns.scatterplot(df['ER'],df['W'],data=df,y_jitter=True)
plt.show()

# %% [markdown]
# Earned Runes increases the number of winnings games decreases.
#
# Inverse relationship between ER and Winning Numbers.
#
# We get a trend of datapoints which shows a negative slope.

# %%
plt.figure(figsize=(10,5))
sns.set_style('darkgrid')
plt.title(' Runs allowed Vs Number of Wins  ',fontsize=12)
sns.scatterplot(df['RA'],df['W'],data=df,y_jitter=True)
plt.show()

# %% [markdown]
# A complete inverse proportation we get from this plot.
#
# We are getting Negative slope
#
# As Runs allowed increases we can see that the number of wininigs are getting less.

# %%
plt.figure(figsize=(10,5))
sns.set_style('darkgrid')
plt.title(' E Vs Number of Wins  ',fontsize=12)
sns.scatterplot(df['E'],df['W'],data=df,y_jitter=True)
plt.show()

# %% [markdown]
#  A complete moderate datapoints we are getting from this scatter plot.

# %%
plt.figure(figsize=(10,5))
sns.set_style('darkgrid')
plt.title(' Dubles Vs Number of Wins  ',fontsize=12)
sns.scatterplot(df['2B'],df['W'],data=df,y_jitter=True)
plt.show()

# %% [markdown]
# There is some positive linear relation we can see here in this plot.
#
# If any team take more double in the match/Tournament , the number of winning games inreases.

# %%
plt.figure(figsize=(10,5))
sns.set_style('darkgrid')
plt.title(' Triples Vs Number of Wins  ',fontsize=12)
sns.scatterplot(df['3B'],df['W'],data=df,y_jitter=True)
plt.show()

# %% [markdown]
# There is no such a relation with number of wins and Triples.
#
# data points are scatter all across the x & Y irrespective of X and Y values.
#
# We do not get any trend here.

# %%
sns.pairplot(df)

# %% [markdown]
# # Data Distribution

# %%
plt.figure(figsize=(16,12))
plot=1
for col in df:
    if plot<=10:
        plt.subplot(4,3,plot)
        sns.distplot(df[col])
        plt.xlabel(col)
        plot=plot+1
plt.show()

# %% [markdown]
# All of our data are Normally distributed.

# %% [markdown]
# # Outliers Detection

# %%
plt.figure(figsize=(14,10))
plot=1
for col in df:
    if plot<=5:
        plt.subplot(3,3,plot)
        sns.boxplot(df[col])
        plt.xlabel(col)
        plot=plot+1
plt.show()

# %%
from scipy.stats import zscore
z =np.abs(zscore(df))
print(z.shape)
df_baseball = df.loc[(z<3).all(axis=1)]
print(df_baseball.shape)
# Out:
# (30, 17)
# (29, 17)

# %% [markdown]
# We have dropped outliers from our data.

# %% [markdown]
# # Skewness

# %%
df_baseball.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.783772
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG     0.854980
# SHO    0.526943
# SV     0.627480
# E      0.840271
# dtype: float64

# %%
for i in df_baseball:
    if df_baseball[i].skew()>=.55:
        df_baseball[i]=np.log1p(df_baseball[i])

# %%
df_baseball.skew()
# Out:
# W      0.119013
# R     -0.215364
# AB     0.169573
# H      0.738455
# 2B    -0.335304
# 3B     0.090124
# HR     0.450862
# BB     0.151193
# SO    -0.233815
# SB     0.494966
# RA     0.018155
# ER     0.018461
# ERA    0.016693
# CG    -0.275681
# SHO    0.526943
# SV     0.109983
# E      0.586101
# dtype: float64

# %% [markdown]
# Skewed data has been normalised to it's possible extent.

# %% [markdown]
# # Splitting data into Input and Output Variable

# %%
x=df_baseball.drop(['W'],axis=1)
y=df_baseball[['W']]

# %%
x
# Out:
#       R    AB         H   2B  3B   HR   BB    SO   SB   RA   ER   ERA  \
# 0   724  5575  7.311886  300  42  139  383   973  104  641  601  3.73
# 1   696  5467  7.207860  277  44  156  439  1264   70  700  653  4.07
# 2   669  5439  7.241366  303  29  141  533  1157   86  640  584  3.67
# 3   622  5533  7.231287  260  27  136  404  1231   68  701  643  3.98
# 4   689  5605  7.323831  289  49  151  455  1259   83  803  746  4.64
# 6   764  5567  7.242798  272  19  212  554  1227   63  698  652  4.03
# 7   713  5485  7.223296  246  20  217  418  1331   44  693  646  4.05
# 8   644  5485  7.232733  278  32  167  436  1310   87  642  604  3.74
# 9   748  5640  7.310550  294  33  161  478  1148   71  753  694  4.31
# 10  751  5511  7.258412  279  32  172  503  1233  101  733  680  4.24
# 11  729  5459  7.218177  278  26  230  486  1392  121  618  572  3.57
# 12  661  5417  7.194437  243  21  176  435  1150   52  675  630  3.94
# 8  -1.013995 -0.541454  0.890486  0.818231  0.768604  0.186270 -0.326982
# 9  -0.181661  0.774370  0.612808  0.618110  0.614123  0.787648 -0.570122
# 10  1.375292  1.651587 -0.983844 -0.925686 -0.864490  0.787648  0.402439
# 11 -0.994411 -1.374810 -0.192460 -0.096610 -0.047943 -0.240415  0.159299
# 12  0.826931 -0.629176  0.515620  0.575226  0.437572  1.016282  0.159299
# 13 -1.297968 -0.234429  0.557272  0.389399  0.393434  0.787648  0.888719
# 14  0.151272 -0.629176 -2.275049 -2.269360 -2.254827 -0.841793  0.888719
# 15  0.689841  0.642788 -1.289290 -1.497462 -1.658968 -1.869855  0.402439
# 16  2.609104  0.511205 -1.122683 -1.297340 -1.327935  1.016282  2.347560
# 17  0.464621  0.028736  0.668344  0.646698  0.702398 -0.841793 -1.056402
# 18  0.033766  2.221778  0.904370  0.903998  0.812742 -0.240415 -0.813262
# 19  0.376492 -1.418671 -1.053264 -1.140102 -1.173453 -0.841793  0.645579
# 20  0.905268 -1.155506 -0.747817 -0.854214 -0.754146  0.517232  0.402439
# 21 -0.994411  1.256840 -0.150808  0.017745  0.128608 -1.869855  0.159299
# 22 -1.415474 -0.629176  0.987674  0.875409  0.989293  0.186270 -0.326982
# 23  0.219817  0.204180  1.667986  1.604423  1.607220 -0.841793 -1.056402
# 24  0.063143 -1.067784 -1.303174 -1.197279 -1.151385  1.016282  2.347560
# 25 -0.906281  0.423484 -0.858889 -0.568326 -0.533457  1.214333  1.618139
# 26  0.591919  2.134056  0.335129  0.317927  0.172746 -0.841793  0.159299
# 27  0.738802 -0.058985  0.585040  0.260750  0.283090 -0.841793 -1.299542
# 28  0.307947  0.598927  2.153924  2.319144  2.379630  0.517232 -1.785822
#
#           SV         E
# 0   1.554812 -0.435733
# 1   0.296229 -0.598110
# 2  -0.672787 -1.197382
# 3  -0.825263  0.538291
# 4  -1.142637 -0.598110
# 5   0.667088 -0.045239
# 6   0.035297 -1.378259
# 7   1.952930  0.105172
# 8  -0.379227  0.252482
# 9   0.296229  1.699369
# 10 -0.524172 -0.680704
# 11  0.422470 -0.045239
# 12  0.296229  0.030362
# 13 -2.411864  2.104416
# 14  2.142301  0.179207
# 15  1.345147  1.875780
# 16  0.667088  1.206466
# 17 -0.379227  1.518492
# 18 -1.142637 -0.276965
# 19  0.901919 -0.435733
# 20 -0.237774 -0.276965
# 21 -1.142637 -1.378259
# 22  0.167213 -0.276965
# 23 -1.142637  1.579295
# 24  0.546053 -1.563835
# 25 -0.237774 -1.287248
# 26  0.167213 -0.598110
# 27 -0.237774 -0.121649
# 28 -0.981805  0.105172

# %% [markdown]
# # Feature Importance

# %%
from sklearn.ensemble import ExtraTreesRegressor
et=ExtraTreesRegressor()
et.fit(x,y)
# Out:
# ExtraTreesRegressor()

# %%
print(et.feature_importances_)
# Out:
# [0.05705396 0.01242211 0.01840593 0.0193728  0.00901214 0.03155239
#  0.01511398 0.02798769 0.01440877 0.17266388 0.17308894 0.20606755
#  0.0132388  0.0250128  0.18704211 0.01755614]

# %%
plt.figure(figsize=(15,6))
plt.title('Important Features',fontsize=15)
feat_importance=pd.Series(et.feature_importances_,index=x.columns)
feat_importance.nlargest().plot(kind='barh')
# Out:
# <AxesSubplot:title={'center':'Important Features'}>

# %% [markdown]
# We can see that SV(Saves),RA(Runs Allowed),ERA(Earned Run Average) are the most important Features for prediction of Number of win counts for our Machine Learning Model

# %% [markdown]
# # Model Building

# %%
## Importing machine learning Library
from sklearn.linear_model import LinearRegression,Lasso,Ridge,ElasticNet
from sklearn.tree import DecisionTreeRegressor
from sklearn.naive_bayes import GaussianNB
from sklearn.neighbors import KNeighborsRegressor
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.ensemble import AdaBoostRegressor
from sklearn.ensemble import GradientBoostingRegressor
from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score,accuracy_score
from sklearn.model_selection import cross_val_score,GridSearchCV,train_test_split

# %%
def maxr2_score(clf,x,y):
    maxr2_score1=0
    for i in range(42,100):
        x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=.20,random_state=i)
        clf.fit(x_train,y_train)
        pred=clf.predict(x_test)
        r2_cscore=r2_score(y_test,pred)
        if r2_cscore>maxr2_score1:
            maxr2_score1=r2_cscore
            final_r=i
    print('max r2 score corresponding to',final_r,'is',maxr2_score1)
    print('\n')
    print('cross validation score',cross_val_score(clf,x,y,scoring='r2').mean())
    print('\n')
    print('Standard Deviation',cross_val_score(clf,x,y,scoring='r2').std())
    print('\n')
    print('Training accuracy',clf.score(x_train,y_train))
    print('\n')
    print('Test Accuracy',clf.score(x_test,y_test))
    print('\n')
    print('MAE',mean_absolute_error(y_test,pred))
    print('\n')
    print('MSE',mean_squared_error(y_test,pred))
    print('\n')
    print('RMSE',np.sqrt(mean_squared_error(y_test,pred)))
    
    return final_r

# %%
#LINERAR rEGRESSION
lr=LinearRegression()
maxr2_score(lr,x,y)
# Out:
# max r2 score corresponding to 73 is 0.8507709590470471
#
#
# cross validation score 0.04078645834638232
#
#
# Standard Deviation 0.44737734920591693
#
#
# Training accuracy 0.9632661736539144
#
#
# Test Accuracy 0.849090110876999
#
#
# MAE 4.442997113976799
#
#
# MSE 23.022141973986706
#
#
# RMSE 4.798139428360404
# 73

# %%
## Lasso
lasso=Lasso()
maxr2_score(lasso,x,y)
# Out:
# max r2 score corresponding to 82 is 0.9569861780928952
#
#
# cross validation score 0.49033824821340977
#
#
# Standard Deviation 0.6002031960611405
#
#
# Training accuracy 0.8596965906875517
#
#
# Test Accuracy 0.8752922811726905
#
#
# MAE 3.810352441874779
#
#
# MSE 19.024855327766215
#
#
# RMSE 4.361749113345037
# 82

# %%
## Ridge
rigde=Ridge()
maxr2_score(rigde,x,y)
# Out:
# max r2 score corresponding to 75 is 0.9656470425613889
#
#
# cross validation score 0.3917445799642074
#
#
# Standard Deviation 0.6838140520964888
#
#
# Training accuracy 0.9326037702056971
#
#
# Test Accuracy 0.9196126869876206
#
#
# MAE 3.0388280178362983
#
#
# MSE 12.263531196221889
#
#
# RMSE 3.5019324945266845
# 75

# %%
## Decision Tree
dt=DecisionTreeRegressor()
maxr2_score(dt,x,y)
# Out:
# max r2 score corresponding to 65 is 0.8201595358955764
#
#
# cross validation score -2.238612247775022
#
#
# Standard Deviation 3.9143277697740255
#
#
# Training accuracy 1.0
#
#
# Test Accuracy 0.26365622723962123
#
#
# MAE 9.0
#
#
# MSE 112.33333333333333
#
#
# RMSE 10.598742063723098
# 65

# %%
## KNN
knn=KNeighborsRegressor()
maxr2_score(knn,x,y)
# Out:
# max r2 score corresponding to 51 is 0.7973065326633166
#
#
# cross validation score 0.027111560669320613
#
#
# Standard Deviation 0.7888810870744435
#
#
# Training accuracy 0.6182682583105364
#
#
# Test Accuracy 0.6643408594319009
#
#
# MAE 6.633333333333333
#
#
# MSE 51.20666666666668
#
#
# RMSE 7.1558833603313206
# 51

# %%
##SVm
svm=SVR()
maxr2_score(svm,x,y)
# Out:
# max r2 score corresponding to 54 is 0.22178358793156283
#
#
# cross validation score -0.2972022350274798
#
#
# Standard Deviation 0.49177877863138775
#
#
# Training accuracy 0.21985396844426752
#
#
# Test Accuracy 0.15457624455188335
#
#
# MAE 9.978375554568848
#
#
# MSE 128.97409069225156
#
#
# RMSE 11.356676040649022
# 54

# %%
## random Forest
rf=RandomForestRegressor()
maxr2_score(rf,x,y)
# Out:
# max r2 score corresponding to 46 is 0.8114073092736411
#
#
# cross validation score -0.6674057913014135
#
#
# Standard Deviation 2.0736040436878524
#
#
# Training accuracy 0.9383908687722788
#
#
# Test Accuracy 0.7167757465404224
#
#
# MAE 5.983333333333334
#
#
# MSE 43.207433333333334
#
#
# RMSE 6.573236138564728
# 46

# %%
## AdaBoost
Adb=AdaBoostRegressor()
maxr2_score(Adb,x,y)
# Out:
# max r2 score corresponding to 46 is 0.8055513256518281
#
#
# cross validation score -1.1713651434982233
#
#
# Standard Deviation 3.368888027303172
#
#
# Training accuracy 0.9926301097478976
#
#
# Test Accuracy 0.5744917605708626
#
#
# MAE 7.070767195767196
#
#
# MSE 64.91364585957841
#
#
# RMSE 8.056900511957338
# 46

# %%
## Gradient Boost
gnb=GradientBoostingRegressor()
maxr2_score(gnb,x,y)
# Out:
# max r2 score corresponding to 94 is 0.8176723865509167
#
#
# cross validation score -1.210891968553144
#
#
# Standard Deviation 3.6316942161939125
#
#
# Training accuracy 0.9999998270821823
#
#
# Test Accuracy 0.6922343769595332
#
#
# MAE 5.86668794490496
#
#
# MSE 46.95135560384009
#
#
# RMSE 6.8521059247387655
# 94

# %% [markdown]
# From all above models we can see that Ridge Regressor has a very good training and Testing Accuracy.
#
# We will choose ridge regressor as our best model becasue the difference between the Test accuracy & Training accuracy score is very less as compare to other models.

# %% [markdown]
# # Hyperparameter Tuning of Ridge Regressor

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,random_state=75,test_size=.20)
ridge=Ridge()
parameters={"alpha":[0.001,0.01,0.1,1],'solver': ['auto', 'svd', 'cholesky', 'lsqr']}
glf=GridSearchCV(estimator=ridge,param_grid=parameters,scoring='r2',n_jobs=-1)
glf.fit(x_train,y_train)
glf.best_params_
# Out:
# {'alpha': 1, 'solver': 'svd'}

# %%
ridge1=Ridge(alpha=1,solver='svd')
ridge1.fit(x_train,y_train)
pred=ridge1.predict(x_test)
print('Training accuracy',ridge1.score(x_train,y_train))
print('\n')
print('Test Accuracy',ridge1.score(x_test,y_test))
print('\n')

print('Error:')
print('MAE',mean_absolute_error(y_test,pred))
print('\n')
print('MSE',mean_squared_error(y_test,pred))
print('\n')
print('RMSE',np.sqrt(mean_squared_error(y_test,pred)))
print('\n')
print('R2 score',r2_score(pred,y_test))
# Out:
# Training accuracy 0.9179210449221076
#
#
# Test Accuracy 0.9656470425613889
#
#
# Error:
# MAE 1.717957231883311
#
#
# MSE 4.642420498301201
#
#
# RMSE 2.154627693663386
#
#
# R2 score 0.9662212521645058

# %% [markdown]
# we can see that our test accuracy has imporved from 91.96 to 96.56. Our RMSE score also improved from 3.50 to 2.15. Hence this is our final Model

# %% [markdown]
# # Saving the Model

# %%
import joblib
joblib.dump(ridge1,'baseballR_1.pkl')
# Out:
# ['baseballR_1.pkl']

# %% [markdown]
# # Loading the Model

# %%
loaded_model=joblib.load('baseballR_1.pkl')
prediction=loaded_model.predict(x_test)
